# %% [markdown]
# # Assignment 1: Prompt-Only Pricing Agent (Baseline)
#
# ## Objective
# Build a simple LLM price recommender using **prompts only** - no tools, no data lookup, just pure LLM reasoning!
#
# ## Requirements
# **User Input:**
# - Cost Price
# - Current Price
# - Target Margin (%)
# - Competitor Price
# - Price Elasticity (Low/Medium/High)
#
# **Agent Action:**
# - Computes recommended price using verbal reasoning
# - No tools, no data lookup
# - Clear explanation of reasoning

# %% [markdown]
# ## ️Setup & Dependencies
#
# First, let's install the required packages and set up our environment.

# %%
# Install required packages
# !pip install -q langchain langchain-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.2 MB/s eta 0:00:00

# %%
# Import required libraries
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage
import os
import getpass

# %%
# Set up your Groq API key
print("🔑 Please enter your Groq API key:")
print("(You can get one free at: https://console.groq.com/)")
groq_api_key = getpass.getpass("Groq API Key: ")
os.environ["GROQ_API_KEY"] = groq_api_key
print("✅ API key set successfully!")
# Out:
# 🔑 Please enter your Groq API key:
# (You can get one free at: https://console.groq.com/)
# Groq API Key: ··········
# ✅ API key set successfully!

# %% [markdown]
# ## Initialize the Language Model
#
# Let's set up our LLM for pricing recommendations.

# %%
# TODO: Initialize ChatGroq with appropriate parameters
# Hint: llm = ChatGroq() - use model, temperature, max_tokens etc

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0,
    max_tokens=1000,
    api_key=groq_api_key
)

# %% [markdown]
# ## Prompt Engineering for Pricing
#
# Now let's create effective prompts for our pricing agent. We'll start with a basic approach and then improve it.

# %% [markdown]
# ### Basic Prompt
#
# **Task:** Create a basic pricing prompt template. Fill in the template below.

# %%
# TODO: Complete this basic pricing prompt template
# HINT: basic_pricing_prompt = PromptTemplate() # Use input_varialbles, and a template string
# Make sure template can handle cost_price, current_price, target_margin, competitor_price, price_elasticity as variables
basic_pricing_prompt = PromptTemplate(
    input_variables=["cost_price", "current_price", "target_margin", "competitor_price", "price_elasticity"],
    template= "You are a retail pricing agent. Recommend an optimal selling price balancing price-elasticity={price_elasticity}, margin:{target_margin}, competitor-price:{competitor_price}, cost={cost_price} and current-price={current_price}. Show reasoning and keep response short."
)

# %% [markdown]
# ### Test the Basic Prompt
#
# Let's test our basic prompt with the example from the assignment.

# %%
# Test with the assignment example
test_input = {
    "cost_price": 400,
    "current_price": 599,
    "target_margin": 25,
    "competitor_price": 579,
    "price_elasticity": "Medium"
}

# TODO: Create chain and get response
basic_chain = basic_pricing_prompt | llm
basic_response = basic_chain.invoke(test_input)

print("📊 Basic Pricing Recommendation:")
print(basic_response.content)
# Out:
# 📊 Basic Pricing Recommendation:
# To determine the optimal selling price, we'll consider the price-elasticity, margin, competitor price, and cost.
#
# Given:
# - Price-elasticity: Medium (neither highly elastic nor inelastic)
# - Margin: 25% (desired margin)
# - Competitor price: $579
# - Cost: $400
# - Current price: $599
#
# Since the price-elasticity is medium, we can adjust the price without significantly affecting demand.
#
# To achieve a 25% margin, the optimal selling price should be:
# Optimal price = (Cost + Desired margin) / (1 - Desired margin)
# Optimal price = ($400 + ($400 * 0.25)) / (1 - 0.25)
# Optimal price = $500
#
# However, considering the competitor price ($579) and the current price ($599), we should adjust the optimal price to be competitive while maintaining the desired margin.
#
# Recommended optimal selling price: $579 (competitor price) is too low for a 25% margin, so we'll aim for a price between $579 and $599.
# Recommended optimal selling price: $587 (a balance between maintaining the desired margin and being competitive)

# %% [markdown]
# ### Improved Prompt with Chain-of-Thought
#
# **Task:** Create an improved prompt that uses chain-of-thought reasoning for better explanations.

# %%
# TODO: Create an improved prompt with step-by-step reasoning
# Hint: improved_pricing_prompt = PromptTemplate() # input_variables and template.
# Use COT style prompting -
# ANALYSIS STEPS:
# 1. Calculate minimum price based on target margin
# 2. Analyze competitive positioning
# 3. Consider price elasticity impact
# 4. Recommend optimal price
improved_pricing_prompt = PromptTemplate(
    input_variables=["cost_price", "current_price", "target_margin", "competitor_price", "price_elasticity"],
    template="""
   You are a retail pricing agent.
   Recommend an optimal selling price following the factors and steps below:

   price elasticity={price_elasticity}
   margin:{target_margin}
   competitor-price:{competitor_price}
   cost={cost_price}
   current-price={current_price}

   Follow these analysis steps:
    1. Calculate minimum price based on target margin
    2. Analyze competitive positioning
    3. Consider price elasticity impact
    4. Recommend optimal price
   """)

# %%
# TODO: Test the improved prompt with the same data
improved_chain = improved_pricing_prompt | llm
improved_response = improved_chain.invoke(test_input)

print("📈 Improved Pricing Analysis:")
print(improved_response.content)
# Out:
# 📈 Improved Pricing Analysis:
# To determine the optimal selling price, I'll follow the steps you provided.
#
# **Step 1: Calculate minimum price based on target margin**
#
# To calculate the minimum price, we need to divide the cost by (1 - target margin).
#
# Cost = $400
# Target Margin = 25% (or 0.25)
#
# Minimum Price = Cost / (1 - Target Margin)
# = $400 / (1 - 0.25)
# = $400 / 0.75
# = $533.33
#
# **Step 2: Analyze competitive positioning**
#
# The competitor's price is $579. Our current price is $599. To maintain a competitive edge, we should consider pricing below the competitor's price.
#
# **Step 3: Consider price elasticity impact**
#
# Price elasticity is Medium, which means that a small price change will have a moderate impact on demand. To balance revenue and demand, we should aim for a price that is not too high or too low.
#
# **Step 4: Recommend optimal price**
#
# Considering the minimum price ($533.33), competitive positioning, and price elasticity, I recommend the following optimal price:
#
# Optimal Price = $549
#
# This price is below the competitor's price, allowing us to maintain a competitive edge. It's also above the minimum price, ensuring a reasonable margin. The price elasticity impact is moderate, so a $10 price reduction from the current price ($599) should not significantly affect demand.
#
# By pricing at $549, we can balance revenue and demand while maintaining a competitive position in the market.

# %% [markdown]
# ## Class-Based Pricing Agent
#
# Now let's create a reusable class-based pricing agent, similar to the PhysicsTeacherAgent structure.

# %%
class PricingAgent:
    def __init__(self):
        # TODO: Initialize the LLM
        self.llm = ChatGroq(
          model="llama-3.1-8b-instant",
          temperature=0.7,
          max_tokens=1000,
          api_key=groq_api_key
        )

        # TODO: Create the system message for pricing agent persona
        self.system_message = SystemMessage(content="""
        You are a retail pricing agent who provides reasoning in a short and easy to follow manner.
        For arriving at the optimal price, you follow these analysis steps:
          1. Calculate minimum price based on target margin
          2. Analyze competitive positioning
          3. Consider price elasticity impact
          4. Recommend optimal price
        """)

        # TODO: Create the pricing prompt template
        self.pricing_template =  PromptTemplate(
          input_variables=["cost_price", "current_price", "target_margin", "competitor_price", "price_elasticity"],
          template="""
            Recommend an optimal selling price following the factors:

            price elasticity= {price_elasticity}
            margin = {target_margin}
            competitor price = {competitor_price}
            cost = {cost_price}
            current price = {current_price}
          """)
        pass

    def get_price_recommendation(self, cost_price, current_price, target_margin, competitor_price, price_elasticity):
        """Get price recommendation with detailed analysis"""
        # TODO: Implement the price recommendation logic
        messages = [
            self.system_message,
            HumanMessage(content=self.pricing_template.format(
                cost_price=cost_price,
                current_price=current_price,
                target_margin=target_margin,
                competitor_price=competitor_price,
                price_elasticity=price_elasticity
            ))
        ]

        response = self.llm.invoke(messages)
        return response.content

    def quick_price_check(self, cost_price, target_margin, competitor_price):
        """Quick price check with minimal inputs"""
        quick_prompt = f"""Quick pricing check:
        Cost: ${cost_price}, Target Margin: {target_margin}%, Competitor: ${competitor_price}

        Provide a quick price recommendation with brief reasoning."""

        response = self.llm.invoke([HumanMessage(content=quick_prompt)])
        return response.content

print("🏗️ Initializing Pricing Agent...")
pricing_agent = PricingAgent()
print("✅ Pricing Agent Ready!")
# Out:
# 🏗️ Initializing Pricing Agent...
# ✅ Pricing Agent Ready!

# %% [markdown]
# ## Testing Our Pricing Agent
#
# Let's test our pricing agent with various scenarios.

# %%
# Test with the assignment example
print("Testing Assignment Example:")
print("=" * 50)

result = pricing_agent.get_price_recommendation(
    cost_price=400,
    current_price=599,
    target_margin=25,
    competitor_price=579,
    price_elasticity="Medium"
)

print(result)
# Out:
# Testing Assignment Example:
# ==================================================
# To determine the optimal selling price, I will follow the steps you provided:
#
# **Step 1: Calculate minimum price based on target margin**
#
# To calculate the minimum price, we need to divide the cost by (1 - margin).
#
# Margin = 25% or 0.25
# Cost = 400
# Minimum price = Cost / (1 - Margin)
# Minimum price = 400 / (1 - 0.25)
# Minimum price = 400 / 0.75
# Minimum price = 533.33
#
# **Step 2: Analyze competitive positioning**
#
# The competitor price is $579, which is higher than the minimum price and the current price. This indicates that the competitor is selling at a premium price.
#
# **Step 3: Consider price elasticity impact**
#
# Since the price elasticity is medium, it means that the demand for the product will decrease if the price increases, but at a moderate rate. This indicates that the price can be adjusted upwards to some extent without significantly impacting demand.
#
# **Step 4: Recommend optimal price**
#
# Considering the factors above, the optimal price should be set above the minimum price to capture a higher margin, but not so high that it loses market share to the competitor.
#
# A good option could be to set the price at $579, which is the competitor's price. This will allow us to compete on price and potentially capture market share. However, we can also consider pricing at $579 - (current price - minimum price) / 2 = 579 - (599 - 533.33) / 2 = 577.33 to gain some price elasticity and still capture good margins.

# %%
# TODO: Test with different scenarios - Add your own test cases!

# Test Case 1: High elasticity scenario
print("\nTest Case 1: High Elasticity Scenario")
print("=" * 50)
result1 = pricing_agent.get_price_recommendation(
    cost_price=100,
    current_price=200,
    target_margin=30,
    competitor_price=180,
    price_elasticity="High"
)
print(result1)

# Test Case 2: Low elasticity scenario
print("\nTest Case 2: Low Elasticity Scenario")
print("=" * 50)
result2 = pricing_agent.get_price_recommendation(
    cost_price=50,
    current_price=100,
    target_margin=40,
    competitor_price=120,
    price_elasticity="Low"
)
print(result2)
# Out:
# Test Case 1: High Elasticity Scenario
# ==================================================
# To determine the optimal selling price, let's follow the steps:
#
# **1. Calculate minimum price based on target margin**
#
# To calculate the minimum price, we'll use the formula:
# Minimum Price = (1 + Margin) * Cost
# Margin = 30% or 0.30
# Cost = $100
#
# Minimum Price = (1 + 0.30) * 100
# Minimum Price = 1.30 * 100
# Minimum Price = $130
#
# **2. Analyze competitive positioning**
#
# The competitor's price is $180. Since the price elasticity is high, we want to position our product slightly higher or at par with the competitor to capture the market.
#
# **3. Consider price elasticity impact**
#
# High price elasticity means that small changes in price can significantly impact demand. To mitigate this, we might want to consider a price slightly lower than the competitor's to capture more market share.
#
# **4. Recommend optimal price**
#
# Considering the minimum price, competitive positioning, and price elasticity, let's recommend an optimal price.
#
# Optimal Price = Minimum Price + (Competitor Price - Minimum Price) * (1 - Price Elasticity Impact)
# Price Elasticity Impact = 0.10 (assuming a 10% price elasticity impact)
# Optimal Price = $130 + ($180 - $130) * (1 - 0.10)
# Optimal Price = $130 + $50 * 0.90
# Optimal Price = $130 + $45
# Optimal Price = $175
#
# However, the current price is $200, which is higher than the competitor's price. To capture more market share and given the high price elasticity, it would be beneficial to reduce the price to $175.
#
# The optimal selling price is $175.
#
# Test Case 2: Low Elasticity Scenario
# ==================================================
# To determine the optimal selling price, we will follow the steps outlined:
#
# 1. **Calculate minimum price based on target margin**:
#    The target margin is 40%. To find the minimum price, we use the formula: Minimum Price = Cost / (1 - Target Margin). Substituting the values, we get:
#    Minimum Price = 50 / (1 - 0.40) = 50 / 0.60 = 83.33.
#
# 2. **Analyze competitive positioning**:
#    The competitor price is $120. Since the current price is $100 and the competitor price is higher, we should consider increasing the price to maintain a competitive edge.
#
# 3. **Consider price elasticity impact**:
#    The price elasticity is low, which means that customers are relatively insensitive to price changes. This means we can consider increasing the price without significantly impacting sales volume.
#
# 4. **Recommend optimal price**:
#    Based on the analysis, we can consider increasing the price above the current price of $100, while taking into account the minimum price of $83.33 and the competitor price of $120. A reasonable price increase is to set the optimal selling price at $105.
#
#    However, to balance the target margin and the competitive positioning, we can also consider setting the optimal price at the midpoint between the current price and the competitor price, which would be ($100 + $120) / 2 = $110.
#
#    Considering the low price elasticity, we can go with a price higher than the current price but lower than the competitor, to achieve a balance between the target margin and competitive positioning.
#
#    So, the recommended optimal price is $110.
#
#    Final Optimal Price = $110

# %%
# Test the quick price check function
print("⚡ Quick Price Check Test:")
print("=" * 30)

quick_result = pricing_agent.quick_price_check(
    cost_price=250,
    target_margin=20,
    competitor_price=350
)
print(quick_result)

# %% [markdown]
# ## Experiment with Different Prompting Strategies
#
# Try different prompting approaches and compare the results.

# %%
few_shot_template = PromptTemplate(
    input_variables=["cost_price", "current_price", "target_margin", "competitor_price", "price_elasticity"],
    template="""You are a pricing expert. Here are some examples of good pricing decisions:

Example 1:
Cost: $200, Current: $400, Target Margin: 30%, Competitor: $380, Elasticity: Medium
Recommendation: $375 (maintains margin above 30%, competitive with market, good for medium elasticity)

Example 2:
Cost: $100, Current: $180, Target Margin: 25%, Competitor: $200, Elasticity: Low
Recommendation: $190 (exceeds margin target, leverages low elasticity for higher profit)

Now analyze this case:
Cost: ${cost_price}, Current: ${current_price}, Target Margin: {target_margin}%, Competitor: ${competitor_price}, Elasticity: {price_elasticity}

Recommendation:"""
)

# Test few-shot approach
few_shot_chain = few_shot_template | llm
few_shot_result = few_shot_chain.invoke(test_input)

print("🎯 Few-Shot Prompting Result:")
print(few_shot_result.content)
# Out:
# 🎯 Few-Shot Prompting Result:
# To make a pricing recommendation, let's analyze the given data:
#
# - Cost: $400
# - Current price: $599
# - Target Margin: 25%
# - Competitor price: $579
# - Elasticity: Medium
#
# First, let's calculate the current margin:
# Current margin = (Current price - Cost) / Cost
# Current margin = ($599 - $400) / $400
# Current margin = $199 / $400
# Current margin = 0.4975 or 49.75%
#
# Since the target margin is 25%, the current price is above the target margin. To adjust the price and meet the target margin, we need to calculate the new price.
#
# New price = (Target Margin / Current margin) * Current price
# New price = (0.25 / 0.4975) * $599
# New price ≈ 1.503 * $599
# New price ≈ $902.97
#
# However, this new price is not competitive with the market, and it's also higher than the competitor's price. Considering the medium elasticity, we should aim for a price that balances the target margin with market competitiveness.
#
# Let's calculate the price that maintains the target margin while being competitive with the market:
# Competitive price = (Target Margin / (1 - Target Margin)) * Cost
# Competitive price = (0.25 / (1 - 0.25)) * $400
# Competitive price = (0.25 / 0.75) * $400
# Competitive price ≈ 0.3333 * $400
# Competitive price ≈ $133.33
#
# However, this is not the final price, as we need to consider the competitor's price and the current price. A good pricing strategy would be to set a price that is competitive with the market, while maintaining the target margin.
#
# Considering the competitor's price ($579) and the current price ($599), a good recommendation would be to set the price at $579, which is competitive with the market and maintains the target margin. However, this would result in a lower margin than the target margin.
#
# To balance the target margin with market competitiveness, we could set the price at $599, which is the current price. This would result in a higher margin than the target margin, but it's competitive with the market.
#
# Considering the medium elasticity, a good recommendation would be to set the price at $599, which is competitive with the market and maintains a higher margin than the target margin.
#
# However, if we want to set a price that is closer to the target margin, we could set the price at $579, which is competitive with the market, but it's below the current price.
#
# Considering all the factors, a good recommendation would be to set the price at $579, which is competitive with the market, and it's closer to the target margin.
#
# Recommendation: $579

# %% [markdown]
# ## Compare Different Approaches
#
# Let's compare the different prompting strategies we've implemented.

# %%
# TODO: Create a comparison of all approaches
def compare_pricing_approaches(cost_price, current_price, target_margin, competitor_price, price_elasticity):
    """Compare different prompting approaches for the same input"""

    print(f"📊 PRICING COMPARISON FOR:")
    print(f"Cost: ${cost_price}, Current: ${current_price}, Target Margin: {target_margin}%")
    print(f"Competitor: ${competitor_price}, Elasticity: {price_elasticity}")
    print("="*60)

    # Basic approach
    basic_result = basic_chain.invoke({
        "cost_price": cost_price,
        "current_price": current_price,
        "target_margin": target_margin,
        "competitor_price": competitor_price,
        "price_elasticity": price_elasticity
    })

    # Improved approach
    improved_result = improved_chain.invoke({
        "cost_price": cost_price,
        "current_price": current_price,
        "target_margin": target_margin,
        "competitor_price": competitor_price,
        "price_elasticity": price_elasticity
    })

    # Class-based approach
    class_result = pricing_agent.get_price_recommendation(
        cost_price, current_price, target_margin, competitor_price, price_elasticity
    )

    print("🔴 BASIC APPROACH:")
    print(basic_result.content + "...\n")

    print("🟡 IMPROVED APPROACH:")
    print(improved_result.content + "...\n")

    print("🟢 CLASS-BASED APPROACH:")
    print(class_result + "...")

# Run comparison
compare_pricing_approaches(400, 599, 25, 579, "Medium")
# Out:
# 📊 PRICING COMPARISON FOR:
# Cost: $400, Current: $599, Target Margin: 25%
# Competitor: $579, Elasticity: Medium
# ============================================================
# 🔴 BASIC APPROACH:
# To determine the optimal selling price, we'll consider the price-elasticity, margin, competitor price, and cost.
#
# Given:
# - Price-elasticity: Medium (neither highly elastic nor inelastic)
# - Margin: 25% (desired margin)
# - Competitor price: $579
# - Cost: $400
# - Current price: $599
#
# Since the price-elasticity is medium, we can adjust the price without significantly affecting demand.
#
# To achieve a 25% margin, the optimal selling price should be:
# Optimal price = (Cost + Desired margin) / (1 - Desired margin)
# Optimal price = ($400 + ($400 * 0.25)) / (1 - 0.25)
# Optimal price = $500
#
# However, considering the competitor price ($579) and the current price ($599), we should adjust the optimal price to be competitive while maintaining the desired margin.
#
# Recommended optimal selling price: $579 (competitor price) is too low for a 25% margin, so we'll aim for a price between $579 and $599.
# Recommended optimal selling price: $587 (a balance between maintaining the desired margin and being competitive)...
#
# 🟡 IMPROVED APPROACH:
# To determine the optimal selling price, I'll follow the steps you provided.
#
# **Step 1: Calculate minimum price based on target margin**
#
# To calculate the minimum price, we need to divide the cost by (1 - target margin).
#
# Cost = $400
# Target Margin = 25% (or 0.25)
#
# Minimum Price = Cost / (1 - Target Margin)
# = $400 / (1 - 0.25)
# = $400 / 0.75
# = $533.33
#
# **Step 2: Analyze competitive positioning**
#
# The competitor's price is $579. Our current price is $599. To maintain a competitive edge, we should consider pricing below the competitor's price.
#
# **Step 3: Consider price elasticity impact**
#
# Price elasticity is Medium, which means that a small price change will have a moderate impact on demand. To balance revenue and demand, we should aim for a price that is not too high or too low.
#
# **Step 4: Recommend optimal price**
#
# Considering the minimum price ($533.33), competitive positioning, and price elasticity, I recommend the following optimal price:
#
# Optimal Price = $549
#
# This price is below the competitor's price, allowing us to maintain a competitive edge. It's also above the minimum price, ensuring a reasonable margin. The price elasticity impact is moderate, so a $10 price reduction from the current price ($599) should not significantly affect demand.
#
# By pricing at $549, we can balance revenue and demand while maintaining a competitive position in the market....
#
# 🟢 CLASS-BASED APPROACH:
# To recommend the optimal selling price, we'll follow the analysis steps:
#
# **Step 1: Calculate minimum price based on target margin**
#
# Target margin = 25%
# Target profit = Cost + (Target margin * Cost)
# Target profit = 400 + (25% * 400)
# Target profit = 400 + 100
# Target profit = 500
#
# Minimum selling price = Target profit / (1 - Target margin)
# Minimum selling price = 500 / (1 - 0.25)
# Minimum selling price = 500 / 0.75
# Minimum selling price = 666.67
#
# **Step 2: Analyze competitive positioning**
#
# Competitor price = $579
# Current price = $599
#
# Since the competitor price is lower than the current price, we should consider reducing our price to remain competitive.
#
# **Step 3: Consider price elasticity impact**
#
# Price elasticity = Medium
#
# For medium price elasticity, a price increase of 5-10% can lead to a 1-3% decrease in demand.
#
# **Step 4: Recommend optimal price**
#
# Considering the factors above, we'll aim to find a price that balances profitability, competitiveness, and price elasticity.
#
# Optimal price = Maximum of (Minimum selling price, Competitor price + (Target margin * (Competitor price - Cost)))
# Optimal price = Maximum of ($666.67, $579 + (25% * ($579 - $400)))
# Optimal price = Maximum of ($666.67, $579 + (25% * $179))
# Optimal price = Maximum of ($666.67, $579 + $44.75)
# Optimal price = Maximum of ($666.67, $623.75)
#
# Optimal price = $623.75
#
# However, since the competitor price is $579, we'll consider a price that's close to the competitor price but still maintains some margin. Let's aim for a price that's 10% higher than the competitor price:
#
# Optimal price = Competitor price + (10% * Competitor price)
# Optimal price = $579 + (10% * $579)
# Optimal price = $579 + $57.9
# Optimal price = $636.90
#
# Considering the minimum selling price and competitive positioning, we can round down to the nearest dollar to ensure we remain competitive.
#
# Optimal price = $636
#
# However, since our current price is already higher than the competitor's, let's calculate the optimal price by reducing our current price by 5% and see if that gives a better price point.
#
# Current price = $599
# Reduced price = $599 - (5% * $599)
# Reduced price = $599 - $29.95
# Reduced price = $569.05
#
# Our target margin is 25% and we are reducing our current price of $599 by $29.95. However, our cost is $400, and our minimum selling price based on that cost and target margin is $666.67.
#
# Optimal price = $569.05...
